# %% [markdown]
# # <center> Pandas 03 <center>

# %% [markdown]
# <img src = 'https://github.com/saeed-saffari/alzahra-workshop-spr2021/blob/main/lecture/PIC/Pandas.png?raw=true'
#      width = "550"
#      >

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Real data

# %% [markdown]
# ## from Excel, CSV, ...

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '4. Matplotlib.ipynb',
#  '5. Pandas 01.ipynb',
#  'GDP per capita ppp 2021.xlsx',
#  'Real GDP Growth (IMF).xlsx',
#  '1. Data Structure Basics.ipynb',
#  'worldwide_happiness_report.csv',
#  'README.md',
#  'GDP curent US.xls',
#  'PIC',
#  'Human development index (HDI).xlsx',
#  'Py for Econ-Intro-UT Workshop-Sum 2021.pdf',
#  '.ipynb_checkpoints',
#  'covid19_Confirmed_dataset.csv',
#  '7. Pandas 03.ipynb',
#  '6. Pandas 02.ipynb',
#  'Iran GDP growth 1 IMF.jpg',
#  '2. Conditional Control and Function.ipynb',
#  '3. NumPy.ipynb',
#  '8. Project 01 - Covid19 confirmed cases.ipynb',
#  'first_plot.jpg']

# %%
gdp = pd.read_excel( 'GDP curent US.xls', sheet_name='Data')
gdp.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2021-09-15 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0                NaN             NaN           NaN           NaN
# 1                NaN             NaN           NaN           NaN
# 2     Indicator Name  Indicator Code  1.960000e+03  1.961000e+03
# 3  GDP (current US$)  NY.GDP.MKTP.CD           NaN           NaN
# 4  GDP (current US$)  NY.GDP.MKTP.CD  1.929193e+10  1.970186e+10
#
#      Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...   Unnamed: 55  \
# 0           NaN           NaN           NaN           NaN  ...           NaN
# ...

# %%
gdp.shape
# Out:
# (269, 65)

# %% [markdown]
# ### drop useless data

# %% [markdown]
# #### drop indeces

# %%
gdp.drop([0,1], axis= 0, inplace= True)
gdp.head()
# Out:
#                    Data Source World Development Indicators  \
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
# 5                  Afghanistan                          AFG
# 6   Africa Western and Central                          AFW
#
#           Unnamed: 2      Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 2     Indicator Name  Indicator Code  1.960000e+03  1.961000e+03
# 3  GDP (current US$)  NY.GDP.MKTP.CD           NaN           NaN
# 4  GDP (current US$)  NY.GDP.MKTP.CD  1.929193e+10  1.970186e+10
# 5  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08
# 6  GDP (current US$)  NY.GDP.MKTP.CD  1.040732e+10  1.113130e+10
#
#      Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...   Unnamed: 55  \
# 2  1.962000e+03  1.963000e+03  1.964000e+03  1.965000e+03  ...  2.011000e+03
# ...

# %% [markdown]
# #### drop columns

# %%
gdp.columns
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
gdp.drop(['Data Source', 'Unnamed: 2', 'Unnamed: 3'], axis = 1, inplace= True)
gdp.head()
# Out:
#   World Development Indicators    Unnamed: 4    Unnamed: 5    Unnamed: 6  \
# 2                 Country Code  1.960000e+03  1.961000e+03  1.962000e+03
# 3                          ABW           NaN           NaN           NaN
# 4                          AFE  1.929193e+10  1.970186e+10  2.147035e+10
# 5                          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 6                          AFW  1.040732e+10  1.113130e+10  1.194684e+10
#
#      Unnamed: 7    Unnamed: 8    Unnamed: 9   Unnamed: 10   Unnamed: 11  \
# 2  1.963000e+03  1.964000e+03  1.965000e+03  1.966000e+03  1.967000e+03
# 3           NaN           NaN           NaN           NaN           NaN
# 4  2.570500e+10  2.350165e+10  2.678117e+10  2.912019e+10  3.014009e+10
# 5  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09
# 6  1.268022e+10  1.384262e+10  1.486682e+10  1.583747e+10  1.443065e+10
#
#     Unnamed: 12  ...   Unnamed: 55   Unnamed: 56   Unnamed: 57   Unnamed: 58  \
# ...

# %% [markdown]
# ### change columns

# %%
gdp.columns = gdp.loc[2]
gdp.drop(2, axis = 0, inplace=True)
gdp.head()
# Out:
# 2 Country Code        1960.0        1961.0        1962.0        1963.0  \
# 3          ABW           NaN           NaN           NaN           NaN
# 4          AFE  1.929193e+10  1.970186e+10  2.147035e+10  2.570500e+10
# 5          AFG  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 6          AFW  1.040732e+10  1.113130e+10  1.194684e+10  1.268022e+10
# 7          AGO           NaN           NaN           NaN           NaN
#
# 2        1964.0        1965.0        1966.0        1967.0        1968.0  ...  \
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4  2.350165e+10  2.678117e+10  2.912019e+10  3.014009e+10  3.284101e+10  ...
# 5  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
# 6  1.384262e+10  1.486682e+10  1.583747e+10  1.443065e+10  1.488470e+10  ...
# 7           NaN           NaN           NaN           NaN           NaN  ...
#
# 2        2011.0        2012.0        2013.0        2014.0        2015.0  \
# ...

# %% [markdown]
# ### change index

# %%
gdp.columns
# Out:
# Index(['Country Code',         1960.0,         1961.0,         1962.0,
#                1963.0,         1964.0,         1965.0,         1966.0,
#                1967.0,         1968.0,         1969.0,         1970.0,
#                1971.0,         1972.0,         1973.0,         1974.0,
#                1975.0,         1976.0,         1977.0,         1978.0,
#                1979.0,         1980.0,         1981.0,         1982.0,
#                1983.0,         1984.0,         1985.0,         1986.0,
#                1987.0,         1988.0,         1989.0,         1990.0,
#                1991.0,         1992.0,         1993.0,         1994.0,
#                1995.0,         1996.0,         1997.0,         1998.0,
#                1999.0,         2000.0,         2001.0,         2002.0,
#                2003.0,         2004.0,         2005.0,         2006.0,
#                2007.0,         2008.0,         2009.0,         2010.0,
# ...

# %%
gdp.set_index('Country Code', inplace= True)
gdp.head()
# Out:
# 2                   1960.0        1961.0        1962.0        1963.0  \
# Country Code
# ABW                    NaN           NaN           NaN           NaN
# AFE           1.929193e+10  1.970186e+10  2.147035e+10  2.570500e+10
# AFG           5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# AFW           1.040732e+10  1.113130e+10  1.194684e+10  1.268022e+10
# AGO                    NaN           NaN           NaN           NaN
#
# 2                   1964.0        1965.0        1966.0        1967.0  \
# Country Code
# ABW                    NaN           NaN           NaN           NaN
# AFE           2.350165e+10  2.678117e+10  2.912019e+10  3.014009e+10
# AFG           8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09
# AFW           1.384262e+10  1.486682e+10  1.583747e+10  1.443065e+10
# AGO                    NaN           NaN           NaN           NaN
#
# 2                   1968.0        1969.0  ...        2011.0        2012.0  \
# ...

# %%
gdp.index
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', name='Country Code', length=266)

# %%
gdp.columns
# Out:
# Index([1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0,
#        1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0,
#        1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0,
#        1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0,
#        1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0,
#        2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0,
#        2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0],
#       dtype='object', name=2)

# %% [markdown]
# ### Transpose

# %%
gdp_2 = gdp.T
gdp_2.head()
# Out:
# Country Code  ABW           AFE           AFG           AFW  AGO  ALB  AND  \
# 2
# 1960.0        NaN  1.929193e+10  5.377778e+08  1.040732e+10  NaN  NaN  NaN
# 1961.0        NaN  1.970186e+10  5.488889e+08  1.113130e+10  NaN  NaN  NaN
# 1962.0        NaN  2.147035e+10  5.466667e+08  1.194684e+10  NaN  NaN  NaN
# 1963.0        NaN  2.570500e+10  7.511112e+08  1.268022e+10  NaN  NaN  NaN
# 1964.0        NaN  2.350165e+10  8.000000e+08  1.384262e+10  NaN  NaN  NaN
#
# Country Code  ARB  ARE           ARG  ...  VIR  VNM  VUT           WLD  WSM  \
# 2                                     ...
# 1960.0        NaN  NaN           NaN  ...  NaN  NaN  NaN  1.384628e+12  NaN
# 1961.0        NaN  NaN           NaN  ...  NaN  NaN  NaN  1.440342e+12  NaN
# 1962.0        NaN  NaN  2.445060e+10  ...  NaN  NaN  NaN  1.545697e+12  NaN
# 1963.0        NaN  NaN  1.827212e+10  ...  NaN  NaN  NaN  1.665141e+12  NaN
# 1964.0        NaN  NaN  2.560525e+10  ...  NaN  NaN  NaN  1.824117e+12  NaN
#
# ...

# %%
gdp.index
# Out:
# Index(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG',
#        ...
#        'VIR', 'VNM', 'VUT', 'WLD', 'WSM', 'XKX', 'YEM', 'ZAF', 'ZMB', 'ZWE'],
#       dtype='object', name='Country Code', length=266)

# %%
gdp.columns
# Out:
# Index([1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0,
#        1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0,
#        1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0,
#        1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0,
#        1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0,
#        2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0,
#        2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0],
#       dtype='object', name=2)

# %%
gdp_2.describe()
# Out:
# Country Code           ABW           AFE           AFG           AFW  \
# count         3.300000e+01  6.100000e+01  4.100000e+01  6.100000e+01
# mean          1.895852e+09  3.199256e+11  7.544745e+09  2.327118e+11
# std           8.416992e+08  3.196689e+11  7.512903e+09  2.631711e+11
# min           4.054634e+08  1.929193e+10  5.377778e+08  1.040732e+10
# 25%           1.245688e+09  8.311919e+10  1.673333e+09  5.145977e+10
# 50%           1.941341e+09  2.121032e+11  3.641723e+09  1.174914e+11
# 75%           2.549721e+09  4.705097e+11  1.585657e+10  3.021108e+11
# max           3.202189e+09  9.840320e+11  2.056107e+10  8.469431e+11
#
# Country Code           AGO           ALB           AND           ARB  \
# count         3.800000e+01  3.700000e+01  5.000000e+01  5.300000e+01
# mean          4.488052e+10  6.876568e+09  1.567655e+09  9.838970e+11
# std           4.747549e+10  5.117763e+09  1.310619e+09  9.416545e+11
# ...

# %%
gdp_2.describe()['AFG']
# Out:
# count    4.100000e+01
# mean     7.544745e+09
# std      7.512903e+09
# min      5.377778e+08
# 25%      1.673333e+09
# 50%      3.641723e+09
# 75%      1.585657e+10
# max      2.056107e+10
# Name: AFG, dtype: float64

# %% [markdown]
# ### Plot

# %%
gdp_2.head()
# Out:
# Country Code  ABW           AFE           AFG           AFW  AGO  ALB  AND  \
# 2
# 1960.0        NaN  1.929193e+10  5.377778e+08  1.040732e+10  NaN  NaN  NaN
# 1961.0        NaN  1.970186e+10  5.488889e+08  1.113130e+10  NaN  NaN  NaN
# 1962.0        NaN  2.147035e+10  5.466667e+08  1.194684e+10  NaN  NaN  NaN
# 1963.0        NaN  2.570500e+10  7.511112e+08  1.268022e+10  NaN  NaN  NaN
# 1964.0        NaN  2.350165e+10  8.000000e+08  1.384262e+10  NaN  NaN  NaN
#
# Country Code  ARB  ARE           ARG  ...  VIR  VNM  VUT           WLD  WSM  \
# 2                                     ...
# 1960.0        NaN  NaN           NaN  ...  NaN  NaN  NaN  1.384628e+12  NaN
# 1961.0        NaN  NaN           NaN  ...  NaN  NaN  NaN  1.440342e+12  NaN
# 1962.0        NaN  NaN  2.445060e+10  ...  NaN  NaN  NaN  1.545697e+12  NaN
# 1963.0        NaN  NaN  1.827212e+10  ...  NaN  NaN  NaN  1.665141e+12  NaN
# 1964.0        NaN  NaN  2.560525e+10  ...  NaN  NaN  NaN  1.824117e+12  NaN
#
# ...

# %%
gdp_2.plot(y = 'IRN', figsize = (15,8), lw = 3, c = 'g', fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('GDP (Trillion dollar)', fontsize = 14, fontname = 'Times New Roman')
plt.title('GDP Iran\nSince 1960 - 2020', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(loc = 'upper left', fontsize = 12)
plt.xlim(left = 1960)
plt.show()

# %%
#pd.set_option('display.max_rows', None)
#pd.reset_option('display.max_rows')

# %%
gdp_2.loc[:, 'IRN']
# Out:
# 2
# 1960.0    4.199134e+09
# 1961.0    4.426949e+09
# 1962.0    4.693566e+09
# 1963.0    4.928628e+09
# 1964.0    5.379846e+09
#               ...
# 2016.0    4.179836e+11
# 2017.0    4.453453e+11
# 2018.0    2.943567e+11
# 2019.0    2.582455e+11
# 2020.0    1.917183e+11
# Name: IRN, Length: 61, dtype: float64

# %%
gdp_2.loc[:, 'IRN'] = gdp_2.loc[:, 'IRN'].interpolate()

# %%
gdp_2.plot(y = 'IRN', figsize = (15,8), lw = 3, c = 'g', fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('GDP (Trillion dollar)', fontsize = 14, fontname = 'Times New Roman')
plt.title('GDP Iran\nSince 1960 - 2020', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(loc = 'upper left', fontsize = 12)
plt.xlim(left = 1960)
plt.show()

# %%
gdp_2.plot(y = ['IRN', 'AUS', 'CAN', 'BRA'], figsize = (15,8), lw = 3, fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('GDP (Trillion dollar)', fontsize = 14, fontname = 'Times New Roman')
plt.title('GDP\nSince 1960 - 2020', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(loc = 'upper left', fontsize = 12)
plt.xlim(left = 1960)
plt.show()

# %%
gdp_2.plot(y = ['IRN', 'NOR', 'SWE'], figsize = (15,8), lw = 3, fontsize = 16)

plt.xlabel('Year', fontsize = 14, fontname = 'Times New Roman')
plt.ylabel('GDP (Trillion dollar)', fontsize = 14, fontname = 'Times New Roman')
plt.title('GDP\nSince 1960 - 2020', fontsize = 16, fontname = 'Times New Roman')

plt.grid()
plt.legend(loc = 'upper left', fontsize = 12)
plt.xlim(left = 1960)
plt.show()

# %% [markdown]
# ## Online data

# %% [markdown]
# ### Imports

# %%
# pip install pandas-datareader

# %%
from pandas_datareader import data
import datetime as dt

# %% [markdown]
# ## data reader

# %%
start = dt.datetime(2021, 1, 2)
end = dt.date.today()

price = data.DataReader('GOOG', 'yahoo', start, end)

# %%
price.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2021-01-04  1760.650024  1707.849976  1757.540039  1728.239990  1901900
# 2021-01-05  1747.670044  1718.015015  1725.000000  1740.920044  1145300
# 2021-01-06  1748.000000  1699.000000  1702.630005  1735.290039  2602100
# 2021-01-07  1788.400024  1737.050049  1740.060059  1787.250000  2265000
# 2021-01-08  1809.839966  1773.535034  1787.979980  1807.209961  2050600
#
#               Adj Close
# Date
# 2021-01-04  1728.239990
# 2021-01-05  1740.920044
# 2021-01-06  1735.290039
# 2021-01-07  1787.250000
# 2021-01-08  1807.209961

# %%
price.shape
# Out:
# (187, 6)

# %%
price['Volume'].plot(figsize = (15,8), lw = 2)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Volume', fontsize = 12)
plt.title('Volume timeline of GOOGLE', fontsize = 15)
plt.show()

# %%
price[['Open', 'Close']].plot(figsize = (15,8), lw = 2)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Price', fontsize = 12)
plt.title('Open and Close price timeline of GOOGLE', fontsize = 15)

plt.show()

# %%
price[['Open', 'Close']].plot(figsize = (15,8), lw = 2)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Price', fontsize = 12)
plt.title('Open and Close price timeline of GOOGLE', fontsize = 15)
plt.xlim('2021-02-01', '2021-06-01')                                  # NEW
plt.show()

# %%
price.loc['2021-02-01': '2021-06-01', ['Open', 'Close']]
# Out:
#                    Open        Close
# Date
# 2021-02-01  1853.569946  1901.349976
# 2021-02-02  1922.560059  1927.510010
# 2021-02-03  2073.000000  2070.070068
# 2021-02-04  2068.889893  2062.370117
# 2021-02-05  2070.000000  2098.000000
# ...                 ...          ...
# 2021-05-25  2420.000000  2409.070068
# 2021-05-26  2412.834961  2433.530029
# 2021-05-27  2436.939941  2402.510010
# 2021-05-28  2421.959961  2411.560059
# 2021-06-01  2422.000000  2429.810059
#
# [84 rows x 2 columns]

# %%
price[['Open', 'Close']]
# Out:
#                    Open        Close
# Date
# 2021-01-04  1757.540039  1728.239990
# 2021-01-05  1725.000000  1740.920044
# 2021-01-06  1702.630005  1735.290039
# 2021-01-07  1740.060059  1787.250000
# 2021-01-08  1787.979980  1807.209961
# ...                 ...          ...
# 2021-09-23  2832.189941  2836.530029
# 2021-09-24  2818.919922  2852.659912
# 2021-09-27  2831.709961  2830.020020
# 2021-09-28  2781.770020  2723.679932
# 2021-09-29  2742.194092  2690.419922
#
# [187 rows x 2 columns]

# %%
price.loc['2021-02-01': '2021-06-01', ['Open', 'Close']].plot(figsize = (15,8), lw = 2)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Price', fontsize = 12)
plt.title('Open and Close price timeline of GOOGLE', fontsize = 15)                            
plt.show()

# %%
price_2 = data.DataReader(['GOOG', 'FB'], 'yahoo', start, end)

# %%
price_2.head()
# Out:
# Attributes    Adj Close                    Close                     High  \
# Symbols            GOOG          FB         GOOG          FB         GOOG
# Date
# 2021-01-04  1728.239990  268.940002  1728.239990  268.940002  1760.650024
# 2021-01-05  1740.920044  270.970001  1740.920044  270.970001  1747.670044
# 2021-01-06  1735.290039  263.309998  1735.290039  263.309998  1748.000000
# 2021-01-07  1787.250000  268.739990  1787.250000  268.739990  1788.400024
# 2021-01-08  1807.209961  267.570007  1807.209961  267.570007  1809.839966
#
# Attributes                      Low                     Open              \
# Symbols             FB         GOOG          FB         GOOG          FB
# Date
# 2021-01-04  275.000000  1707.849976  265.200012  1757.540039  274.779999
# 2021-01-05  272.399994  1718.015015  268.209991  1725.000000  268.290009
# 2021-01-06  267.750000  1699.000000  260.010010  1702.630005  262.000000
# ...

# %%
price_2['Open']
# Out:
# Symbols            GOOG          FB
# Date
# 2021-01-04  1757.540039  274.779999
# 2021-01-05  1725.000000  268.290009
# 2021-01-06  1702.630005  262.000000
# 2021-01-07  1740.060059  265.899994
# 2021-01-08  1787.979980  268.309998
# ...                 ...         ...
# 2021-09-23  2832.189941  345.359985
# 2021-09-24  2818.919922  343.239990
# 2021-09-27  2831.709961  349.809998
# 2021-09-28  2781.770020  347.970001
# 2021-09-29  2742.194092  343.149994
#
# [187 rows x 2 columns]

# %%
price_2['Open']['FB']
# Out:
# Date
# 2021-01-04    274.779999
# 2021-01-05    268.290009
# 2021-01-06    262.000000
# 2021-01-07    265.899994
# 2021-01-08    268.309998
#                  ...
# 2021-09-23    345.359985
# 2021-09-24    343.239990
# 2021-09-27    349.809998
# 2021-09-28    347.970001
# 2021-09-29    343.149994
# Name: FB, Length: 187, dtype: float64

# %%
close_1 = price_2['Adj Close']
close_1.head()
# Out:
# Symbols            GOOG          FB
# Date
# 2021-01-04  1728.239990  268.940002
# 2021-01-05  1740.920044  270.970001
# 2021-01-06  1735.290039  263.309998
# 2021-01-07  1787.250000  268.739990
# 2021-01-08  1807.209961  267.570007

# %%
percentage = close_1.pct_change()
percentage
# Out:
# Symbols         GOOG        FB
# Date
# 2021-01-04       NaN       NaN
# 2021-01-05  0.007337  0.007548
# 2021-01-06 -0.003234 -0.028269
# 2021-01-07  0.029943  0.020622
# 2021-01-08  0.011168 -0.004354
# ...              ...       ...
# 2021-09-23  0.006301  0.008013
# 2021-09-24  0.005686  0.020234
# 2021-09-27 -0.007936  0.001757
# 2021-09-28 -0.037576 -0.036569
# 2021-09-29 -0.012211 -0.003053
#
# [187 rows x 2 columns]

# %%
percentage.plot(figsize = (15,8))

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Percantage', fontsize = 12)
plt.title('Google and Facebook Percantage in Adj Price in 2021', fontsize = 15)                            
plt.show()

# %%
price_2['Adj Close']['GOOG'].pct_change().plot(figsize = (15,8), c = 'g')

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Percantage', fontsize = 12)
plt.title('Google Percantage in Adj Price in 2021', fontsize = 15)                            
plt.show()

# %%
close_1
# Out:
# Symbols            GOOG          FB
# Date
# 2021-01-04  1728.239990  268.940002
# 2021-01-05  1740.920044  270.970001
# 2021-01-06  1735.290039  263.309998
# 2021-01-07  1787.250000  268.739990
# 2021-01-08  1807.209961  267.570007
# ...                 ...         ...
# 2021-09-23  2836.530029  345.959991
# 2021-09-24  2852.659912  352.959991
# 2021-09-27  2830.020020  353.579987
# 2021-09-28  2723.679932  340.649994
# 2021-09-29  2690.419922  339.609985
#
# [187 rows x 2 columns]

# %%
diffrence = close_1.diff()
diffrence
# Out:
# Symbols           GOOG         FB
# Date
# 2021-01-04         NaN        NaN
# 2021-01-05   12.680054   2.029999
# 2021-01-06   -5.630005  -7.660004
# 2021-01-07   51.959961   5.429993
# 2021-01-08   19.959961  -1.169983
# ...                ...        ...
# 2021-09-23   17.760010   2.750000
# 2021-09-24   16.129883   7.000000
# 2021-09-27  -22.639893   0.619995
# 2021-09-28 -106.340088 -12.929993
# 2021-09-29  -33.260010  -1.040009
#
# [187 rows x 2 columns]

# %%
diffrence.plot(figsize = (15,8))

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Percantage', fontsize = 12)
plt.title('Google and Facebook difference in Adj Price in 2021', fontsize = 15)                            
plt.show()

# %% [markdown]
# | Symbols | Company |
# |---      | ---     |
# |INTC| Intel|
# |MSFT| Microsoft|
# |IBM| IBM|
# |BHP| BHP|
# |TM| Toyota|
# |AAPL| Apple|
# |AMZN| Amazon|
# |BA| Boeing|
# |QCOM| Qualcomm|
# |KO| Coca-Cola|
# |GOOG| Google|
# |SNE| Sony|
# |PTR| PetroChina|

# %% [markdown]
# ## Extra Work

# %% [markdown]
# # World Bank

# %% [markdown]
# ### Imports

# %%
# pip install pandas-datareader

# %%
from pandas_datareader import wb

# %%
growth = wb.download(country= 'all', indicator= 'NY.GDP.MKTP.KD.ZG', start= 1960, end = 2020)

# %%
growth.head()
# Out:
#                                   NY.GDP.MKTP.KD.ZG
# country                     year
# Africa Eastern and Southern 2020          -3.575173
#                             2019           1.672925
#                             2018           2.385829
#                             2017           2.832288
#                             2016           2.004539

# %%
growth.unstack().head()
# Out:
#                             NY.GDP.MKTP.KD.ZG                        \
# year                                     1960       1961       1962
# country
# Afghanistan                               NaN        NaN        NaN
# Africa Eastern and Southern               NaN   1.063696   7.453563
# Africa Western and Central                NaN   1.898596   3.816073
# Albania                                   NaN        NaN        NaN
# Algeria                                   NaN -13.605441 -19.685042
#
#                                                                       \
# year                              1963      1964      1965      1966
# country
# Afghanistan                        NaN       NaN       NaN       NaN
# Africa Eastern and Southern   5.740520  5.473950  5.594137  4.058715
# Africa Western and Central    7.040888  5.233236  4.175162 -1.796436
# Albania                            NaN       NaN       NaN       NaN
# ...

# %%
growth2 = growth.unstack()
growth2.head()
# Out:
#                             NY.GDP.MKTP.KD.ZG                        \
# year                                     1960       1961       1962
# country
# Afghanistan                               NaN        NaN        NaN
# Africa Eastern and Southern               NaN   1.063696   7.453563
# Africa Western and Central                NaN   1.898596   3.816073
# Albania                                   NaN        NaN        NaN
# Algeria                                   NaN -13.605441 -19.685042
#
#                                                                       \
# year                              1963      1964      1965      1966
# country
# Afghanistan                        NaN       NaN       NaN       NaN
# Africa Eastern and Southern   5.740520  5.473950  5.594137  4.058715
# Africa Western and Central    7.040888  5.233236  4.175162 -1.796436
# Albania                            NaN       NaN       NaN       NaN
# ...

# %%
growth2.columns = np.arange(1960, 2021)
growth2.head()
# Out:
#                              1960       1961       1962       1963      1964  \
# country
# Afghanistan                   NaN        NaN        NaN        NaN       NaN
# Africa Eastern and Southern   NaN   1.063696   7.453563   5.740520  5.473950
# Africa Western and Central    NaN   1.898596   3.816073   7.040888  5.233236
# Albania                       NaN        NaN        NaN        NaN       NaN
# Algeria                       NaN -13.605441 -19.685042  34.313729  5.839413
#
#                                  1965      1966      1967       1968  \
# country
# Afghanistan                       NaN       NaN       NaN        NaN
# Africa Eastern and Southern  5.594137  4.058715  5.813018   4.046609
# Africa Western and Central   4.175162 -1.796436 -9.401674   1.422819
# Albania                           NaN       NaN       NaN        NaN
# Algeria                      6.206898 -4.804971  9.452963  10.796239
#
# ...

# %%
growth2.columns
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#             1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#             1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#             1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017, 2018, 2019, 2020],
#            dtype='int64')

# %%
growth3 = growth2.T
growth3.head()
# Out:
# country  Afghanistan  Africa Eastern and Southern  Africa Western and Central  \
# 1960             NaN                          NaN                         NaN
# 1961             NaN                     1.063696                    1.898596
# 1962             NaN                     7.453563                    3.816073
# 1963             NaN                     5.740520                    7.040888
# 1964             NaN                     5.473950                    5.233236
#
# country  Albania    Algeria  American Samoa  Andorra  Angola  \
# 1960         NaN        NaN             NaN      NaN     NaN
# 1961         NaN -13.605441             NaN      NaN     NaN
# 1962         NaN -19.685042             NaN      NaN     NaN
# 1963         NaN  34.313729             NaN      NaN     NaN
# 1964         NaN   5.839413             NaN      NaN     NaN
#
# country  Antigua and Barbuda  Arab World  ...  Uzbekistan  Vanuatu  \
# ...

# %%
growth3.index.rename('year', inplace=True)
growth3.head()
# Out:
# country  Afghanistan  Africa Eastern and Southern  Africa Western and Central  \
# year
# 1960             NaN                          NaN                         NaN
# 1961             NaN                     1.063696                    1.898596
# 1962             NaN                     7.453563                    3.816073
# 1963             NaN                     5.740520                    7.040888
# 1964             NaN                     5.473950                    5.233236
#
# country  Albania    Algeria  American Samoa  Andorra  Angola  \
# year
# 1960         NaN        NaN             NaN      NaN     NaN
# 1961         NaN -13.605441             NaN      NaN     NaN
# 1962         NaN -19.685042             NaN      NaN     NaN
# 1963         NaN  34.313729             NaN      NaN     NaN
# 1964         NaN   5.839413             NaN      NaN     NaN
#
# country  Antigua and Barbuda  Arab World  ...  Uzbekistan  Vanuatu  \
# ...

# %%
growth3['Iran, Islamic Rep.'].plot(figsize = (15,8), lw = 3)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Year', fontsize = 12)
plt.ylabel('GDP Growth', fontsize = 12)
plt.title('Iran GDP Growth', fontsize = 15)                            
plt.show()

# %%
growth3[['Iran, Islamic Rep.', 'China']].plot(figsize = (15,8), lw = 3)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Year', fontsize = 12)
plt.ylabel('GDP Growth', fontsize = 12)
plt.title('Iran and China GDP Growth', fontsize = 15)                            
plt.show()

# %% [markdown]
# ### Second data

# %%
inv = wb.download(country='all', indicator= 'BX.KLT.DINV.CD.WD', start= 1960, end= 2020)

# %%
inv.head()
# Out:
#                                   BX.KLT.DINV.CD.WD
# country                     year
# Africa Eastern and Southern 2020                NaN
#                             2019       1.463269e+10
#                             2018       1.549981e+10
#                             2017       9.979239e+09
#                             2016       1.692200e+10

# %%
inv2 = inv.unstack()
inv2.head()
# Out:
#                             BX.KLT.DINV.CD.WD                                \
# year                                     1960 1961 1962 1963 1964 1965 1966
# country
# Afghanistan                               NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Africa Eastern and Southern               NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Africa Western and Central                NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Albania                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Algeria                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                             ...                              \
# year                        1967 1968 1969  ...          2011          2012
# country                                     ...
# Afghanistan                  NaN  NaN  NaN  ...  5.217342e+07  5.682366e+07
# Africa Eastern and Southern  NaN  NaN  NaN  ...  1.753870e+10  2.463634e+10
# ...

# %%
inv2.columns = np.arange(1960, 2021)

# %%
inv3 = inv2.T

# %%
inv3.head()
# Out:
# country  Afghanistan  Africa Eastern and Southern  Africa Western and Central  \
# 1960             NaN                          NaN                         NaN
# 1961             NaN                          NaN                         NaN
# 1962             NaN                          NaN                         NaN
# 1963             NaN                          NaN                         NaN
# 1964             NaN                          NaN                         NaN
#
# country  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960         NaN      NaN             NaN      NaN     NaN
# 1961         NaN      NaN             NaN      NaN     NaN
# 1962         NaN      NaN             NaN      NaN     NaN
# 1963         NaN      NaN             NaN      NaN     NaN
# 1964         NaN      NaN             NaN      NaN     NaN
#
# country  Antigua and Barbuda  Arab World  ...  Uzbekistan  Vanuatu  \
# 1960                     NaN         NaN  ...         NaN      NaN
# ...

# %%
inv3['Iran, Islamic Rep.'].plot(figsize = (15,8), lw = 3)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Year', fontsize = 12)
plt.ylabel('F inversment', fontsize = 12)
plt.title('Iran foreign inverstment', fontsize = 15)                            
plt.show()

# %%
inv3[['Iran, Islamic Rep.', 'Iraq']].plot(figsize = (15,8), lw = 3)

plt.grid()
plt.legend(fontsize = 13)
plt.xlabel('Year', fontsize = 12)
plt.ylabel('F inversment', fontsize = 12)
plt.title('Iran and China foreign inverstment', fontsize = 15)                            
plt.show()

# %% [markdown]
# ### concat

# %%
data = pd.concat([inv2[2015], growth2[2015]], axis = 1)

# %%
data.columns = ['Inv', 'Growth']

# %%
data.head()
# Out:
#                                       Inv    Growth
# country
# Afghanistan                  1.691466e+08  1.451315
# Africa Eastern and Southern  2.877423e+10  2.763243
# Africa Western and Central   1.556767e+10  2.735166
# Albania                      9.895783e+08  2.218752
# Algeria                     -5.377929e+08  3.700000

# %%
data.corr()
# Out:
#              Inv    Growth
# Inv     1.000000  0.026904
# Growth  0.026904  1.000000
